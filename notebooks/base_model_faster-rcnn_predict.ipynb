# %%
# ============================================================
# Faster R-CNN 추론 환경 설정
# ============================================================
# 이 Notebook은 학습 Notebook에서 저장한
#
# outputs/checkpoints/faster_rcnn_best.pth
#
# checkpoint를 불러와 추론하는 용도입니다.
#
# train.ipynb와 predict.ipynb는 서로 독립된 Notebook이므로
# 필요한 라이브러리와 설정은 predict Notebook에서도
# 별도로 import해야 합니다.
# ============================================================

from pathlib import Path

import sys
import random

import numpy as np
import torch


# ============================================================
# 프로젝트 루트 설정
# ============================================================
# 현재 predict Notebook은 notebooks/ 폴더에 있지만,
# Dataset / config / checkpoint 등의 상대 경로를
# 프로젝트 루트 기준으로 통일하기 위해 작업 위치를 변경합니다.
# ============================================================

PROJECT_ROOT = Path(
    "/Users/apple/dio_folder/python/codeit_cv_project/pill-object-detection"
)

# %cd $PROJECT_ROOT


# ============================================================
# 현재 작업 디렉터리 확인
# ============================================================

print(
    "현재 작업 디렉터리:",
    Path.cwd(),
)


assert Path.cwd() == PROJECT_ROOT, (
    f"프로젝트 루트 설정이 잘못되었습니다.\n"
    f"현재 위치: {Path.cwd()}\n"
    f"예상 위치: {PROJECT_ROOT}"
)


print("프로젝트 루트 설정 완료")
# Out:
# /Users/apple/dio_folder/python/codeit_cv_project/pill-object-detection
# 현재 작업 디렉터리: /Users/apple/dio_folder/python/codeit_cv_project/pill-object-detection
# 프로젝트 루트 설정 완료
